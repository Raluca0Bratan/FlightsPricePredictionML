# %%
import pandas as pd
import joblib
import numpy as np

# ==============================
# LOAD MODELS + FILES
# ==============================

clf = joblib.load('../models/classifier.pkl')
reg = joblib.load('../models/regressor.pkl')
features = joblib.load('../models/features.pkl')

route_stats = pd.read_csv('../models/route_stats.csv')
feature_importance = pd.read_csv('../models/feature_importance.csv')

# ==============================
# LOAD DATA
# ==============================

df = pd.read_csv('../data/final_dataset.csv')

X = df[features]

# ==============================
# PREDICTIONS
# ==============================

df['Prediction'] = clf.predict(X)
df['Decision'] = df['Prediction'].map({1: 'BUY', 0: 'WAIT'})

if hasattr(clf, "predict_proba"):
    probs = clf.predict_proba(X)
    df['Confidence'] = probs.max(axis=1)
else:
    df['Confidence'] = None

# ==============================
# PRICE PREDICTION
# ==============================

df['ExpectedPrice'] = reg.predict(X)

# ==============================
# MERGE ROUTE STATS (FIX)
# ==============================

df = df.merge(
    route_stats,
    on=["Source", "Destination"],
    how="left",
    suffixes=('', '_route')  # 🔥 IMPORTANT
)

# dacă există deja price_avg în df, îl folosim pe acela
if 'price_avg' not in df.columns:
    if 'price_avg_route' in df.columns:
        df['price_avg'] = df['price_avg_route']
    elif 'price_avg_x' in df.columns:
        df['price_avg'] = df['price_avg_x']
    elif 'price_avg_y' in df.columns:
        df['price_avg'] = df['price_avg_y']
    else:
        raise ValueError("price_avg nu există nici după merge!")

# fallback dacă sunt NaN
global_avg = df['price_avg'].mean()
df['price_avg'] = df['price_avg'].fillna(global_avg)

# ==============================
# EXTRA METRICS
# ==============================

df['Price_vs_Avg_%'] = (
    (df['ExpectedPrice'] - df['price_avg']) / df['price_avg']
) * 100

df['DealQuality'] = np.where(
    df['ExpectedPrice'] < df['price_avg'],
    "GOOD DEAL",
    "EXPENSIVE"
)

df['RiskLevel'] = pd.cut(
    df['Confidence'],
    bins=[0, 0.6, 0.8, 1.0],
    labels=["HIGH", "MEDIUM", "LOW"]
)

# ==============================
# TOP FEATURES
# ==============================

top_features = feature_importance.head(5)['Feature'].tolist()
df['TopFeatures'] = ", ".join(top_features)

# ==============================
# SAVE
# ==============================

output_file = '../data/predictions_enriched.csv'
df.to_csv(output_file, index=False)

print("✅ Enriched predictions saved!")
print(df.head())
# Out:
# ✅ Enriched predictions saved!
#    Airline  AirlineID  Source  Destination    Route  Total_Stops  \
# 0        3          3       0            4  BLR-DEL            0
# 1        1          1       2            0  CCU-BLR            2
# 2        4          4       4            3  DEL-COK            2
# 3        3          3       2            0  CCU-BLR            1
# 4        3          3       0            4  BLR-DEL            1
#
#      DepartureDatetime      ArrivalDatetime  DurationMinutes  DayOfWeek  ...  \
# 0  2019-03-24 22:20:00  2019-03-24 01:10:00         0.034111          6  ...
# 1  2019-05-01 05:50:00  2019-05-01 13:15:00         0.132855          2  ...
# 2  2019-06-09 09:25:00  2019-06-09 04:25:00         0.382406          6  ...
# 3  2019-05-12 18:05:00  2019-05-12 23:30:00         0.089767          6  ...
# 4  2019-03-01 16:50:00  2019-03-01 21:35:00         0.075404          4  ...
#
#    ExpectedPrice  price_min_route  price_max_route  price_avg_route  \
# ...
