# %%
import pandas as pd
import joblib

# Load model
model = joblib.load('../models/model.pkl')

# Load data (IMPORTANT: trebuie să fie ca în training)
df = pd.read_csv('../data/final_dataset.csv')

features = joblib.load('../models/features.pkl')
X = df[features]

# Predict
predictions = model.predict(X)
probs = model.predict_proba(X)

# Adăugăm rezultate
df['Prediction'] = predictions
df['Confidence'] = probs.max(axis=1)

# Mapare la text
df['Decision'] = df['Prediction'].map({1: 'BUY', 0: 'WAIT'})

# Save
output_file = '../data/predictions.csv'
df.to_csv(output_file, index=False)

print("✅ Predictions saved!")
df.head()
# Out:
# ✅ Predictions saved!
#    Airline  AirlineID  Source  Destination  Total_Stops  DurationMinutes  \
# 0        3          3       0            4            0         0.034111
# 1        4          4       4            3            2         0.382406
# 2        3          3       0            4            1         0.075404
# 3        8          8       2            0            0         0.025135
# 4        4          4       0            4            1         0.307002
#
#    DayOfWeek  IsWeekend  Price  DepartureHour  DepartureDay  DepartureMonth  \
# 0          6          1   3897       0.956522            24               3
# 1          6          1  13882       0.391304             9               6
# 2          4          0  13302       0.695652             1               3
# 3          0          0   3873       0.391304            24               6
# 4          1          0  11087       0.782609            12               3
#
#    DepartureWeekday  Label  Prediction  Confidence Decision
# 0                 6      1           1    0.974469      BUY
# 1                 6      0           0    0.998861     WAIT
# 2                 4      0           0    0.977889     WAIT
# 3                 0      1           1    0.998552      BUY
# 4                 1      0           0    0.997763     WAIT
