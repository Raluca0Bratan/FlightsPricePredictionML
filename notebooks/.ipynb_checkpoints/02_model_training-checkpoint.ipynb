# %%
import pandas as pd
import numpy as np
import joblib
import os

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.metrics import accuracy_score, classification_report, mean_absolute_error, r2_score

# ==============================
# LOAD DATA
# ==============================

df = pd.read_csv("../data/final_dataset.csv")

print(df.head())
print(df.info())

# ==============================
# VALIDARE DATE (IMPORTANT)
# ==============================

if "Price" not in df.columns:
    raise Exception("❌ Dataset must contain 'Price' column for regression!")

if "Label" not in df.columns:
    raise Exception("❌ Dataset must contain 'Label' column for classification!")

# ==============================
# FEATURES
# ==============================

features = [
    "Airline",
    "AirlineID",
    "Source",
    "Destination",
    "Total_Stops",
    "DurationMinutes",
    "DayOfWeek",
    "IsWeekend",
    "DepartureHour",
    "DepartureDay",
    "DepartureMonth",
    "DepartureWeekday"
]

X = df[features]

# TARGETS
y_class = df["Label"]
y_price = df["Price"]

# ==============================
# TRAIN / TEST SPLIT
# ==============================

X_train, X_test, y_class_train, y_class_test, y_price_train, y_price_test = train_test_split(
    X, y_class, y_price, test_size=0.2, random_state=42
)

# ==============================
# CLASSIFIER MODEL
# ==============================

clf = RandomForestClassifier(
    n_estimators=150,
    max_depth=12,
    random_state=42
)

clf.fit(X_train, y_class_train)

# ==============================
# REGRESSOR MODEL (REAL PRICE)
# ==============================

reg = RandomForestRegressor(
    n_estimators=150,
    max_depth=12,
    random_state=42
)

reg.fit(X_train, y_price_train)

# ==============================
# EVALUARE CLASSIFIER
# ==============================

y_pred_class = clf.predict(X_test)

print("\n=== CLASSIFIER EVALUATION ===")
print("Accuracy:", accuracy_score(y_class_test, y_pred_class))
print("\nClassification Report:\n", classification_report(y_class_test, y_pred_class))

# ==============================
# EVALUARE REGRESSOR
# ==============================

y_pred_price = reg.predict(X_test)

mae = mean_absolute_error(y_price_test, y_pred_price)
r2 = r2_score(y_price_test, y_pred_price)

print("\n=== REGRESSOR EVALUATION ===")
print("MAE (Mean Absolute Error):", mae)
print("R2 Score:", r2)

# ==============================
# FEATURE IMPORTANCE (PENTRU UI + EXPLAINABILITY)
# ==============================

importances = clf.feature_importances_

feature_importance_df = pd.DataFrame({
    "Feature": features,
    "Importance": importances
}).sort_values(by="Importance", ascending=False)

print("\n=== FEATURE IMPORTANCE ===\n", feature_importance_df)

# ==============================
# STATISTICI REALE PE RUTE (FOARTE IMPORTANT)
# ==============================

route_stats = df.groupby(["Source", "Destination"])["Price"].agg([
    "min", "max", "mean", "median", "count"
]).reset_index()

route_stats.rename(columns={
    "min": "price_min",
    "max": "price_max",
    "mean": "price_avg",
    "median": "price_median",
    "count": "samples"
}, inplace=True)

print("\n=== ROUTE STATS SAMPLE ===")
print(route_stats.head())

# ==============================
# SAVE EVERYTHING
# ==============================

os.makedirs("../models", exist_ok=True)

joblib.dump(clf, "../models/classifier.pkl")
joblib.dump(reg, "../models/regressor.pkl")
joblib.dump(features, "../models/features.pkl")

feature_importance_df.to_csv("../models/feature_importance.csv", index=False)
route_stats.to_csv("../models/route_stats.csv", index=False)

print("\n✅ All models and artifacts saved successfully!")
# Out:
#    Airline  AirlineID  Source  Destination    Route  Total_Stops  \
# 0        3          3       0            4  BLR-DEL            0
# 1        1          1       2            0  CCU-BLR            2
# 2        4          4       4            3  DEL-COK            2
# 3        3          3       2            0  CCU-BLR            1
# 4        3          3       0            4  BLR-DEL            1
#
#      DepartureDatetime      ArrivalDatetime  DurationMinutes  DayOfWeek  ...  \
# 0  2019-03-24 22:20:00  2019-03-24 01:10:00         0.034111          6  ...
# 1  2019-05-01 05:50:00  2019-05-01 13:15:00         0.132855          2  ...
# 2  2019-06-09 09:25:00  2019-06-09 04:25:00         0.382406          6  ...
# 3  2019-05-12 18:05:00  2019-05-12 23:30:00         0.089767          6  ...
# 4  2019-03-01 16:50:00  2019-03-01 21:35:00         0.075404          4  ...
#
#    DepartureDay  DepartureMonth  DepartureWeekday  RouteKey  price_min  \
# 0            24               3                 6   BLR-DEL       3257
# 1             1               5                 2   CCU-BLR       3480
# 2             9               6                 6   DEL-COK       3876
# 3            12               5                 6   CCU-BLR       3480
# 4             1               3                 4   BLR-DEL       3257
#
#    price_max     price_avg  price_median  samples  Label
# 0      79512   8017.424022        6121.0     2198      1
# 1      31945   9158.164694        9345.0     2872      1
# 2      52285  10539.014103       10262.0     4538      1
# 3      31945   9158.164694        9345.0     2872      1
# 4      79512   8017.424022        6121.0     2198      1
#
# [5 rows x 23 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9016 entries, 0 to 9015
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Airline            9016 non-null   int64
#  1   AirlineID          9016 non-null   int64
#  2   Source             9016 non-null   int64
#  3   Destination        9016 non-null   int64
#  4   Route              9016 non-null   object
#  5   Total_Stops        9016 non-null   int64
#  6   DepartureDatetime  9016 non-null   object
#  7   ArrivalDatetime    9016 non-null   object
#  8   DurationMinutes    9016 non-null   float64
#  9   DayOfWeek          9016 non-null   int64
#  10  IsWeekend          9016 non-null   int64
#  11  Price              9016 non-null   int64
#  12  DepartureHour      9016 non-null   float64
#  13  DepartureDay       9016 non-null   int64
#  14  DepartureMonth     9016 non-null   int64
#  15  DepartureWeekday   9016 non-null   int64
#  16  RouteKey           9016 non-null   object
#  17  price_min          9016 non-null   int64
#  18  price_max          9016 non-null   int64
#  19  price_avg          9016 non-null   float64
#  20  price_median       9016 non-null   float64
#  21  samples            9016 non-null   int64
#  22  Label              9016 non-null   int64
# dtypes: float64(4), int64(15), object(4)
# memory usage: 1.6+ MB
# None
